# %% [markdown]
# <h1>In this notebook, Data Science Tools and Ecosystem are summarized.</h1>

# %% [markdown]
# In this notebook, Data Science Tools and Ecosystem are summarized.

# %% [markdown]
# Objectives:
#
# - List popular languages for Data Science.
# - List popular libraries for Data Science.
# - Introducing basic Python aritmethinc operators

# %% [markdown]
# Some of the popular languages that Data Scientists use are:
#
# 1. Python
# 2. R
# 3. Rubi

# %% [markdown]
# Some of the commonly used libraries used by Data Scientists include:
#
# 1. ggplot: Histograms, bar charts, scatterplots
# 2. Plotly: Web-based data visualizationa
# 3. Lattice: Complex, multi-variable data sets

# %% [markdown]
# | Data Science Tools |
# ----------------------
# | VSCode             |
# | RStudio            |
# | Jupyter Lab        |

# %% [markdown]
# <h3>Below are a few examples of evaluating arithmetic expressions in Python</h3>

# %%
# This a simple arithmetic expression to mutiply then add integers
(3*4)+5
# Out:
# 17

# %%
# This will convert 200 minutes to hours by diving by 60
200/60
# Out:
# 3.3333333333333335

# %% [markdown]
# <h2>Author:</h2>
# Axel Díaz
